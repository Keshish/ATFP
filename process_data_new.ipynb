# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DevelopmentData = pd.read_excel("DevelopmentData.xlsx", index_col=[0])
DevelopmentData.info()
DevelopmentData
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428 entries, 0 to 427
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   FirstObjectDistance_X   428 non-null    int64
#  1   FirstObjectDistance_Y   428 non-null    int64
#  2   SecondObjectDistance_X  428 non-null    int64
#  3   SecondObjectDistance_Y  428 non-null    int64
#  4   ThirdObjectDistance_X   428 non-null    int64
#  5   ThirdObjectDistance_Y   428 non-null    int64
#  6   FourthObjectDistance_X  428 non-null    int64
#  7   FourthObjectDistance_Y  428 non-null    int64
#  8   VehicleSpeed            428 non-null    int64
#  9   FirstObjectSpeed_X      428 non-null    int64
#  10  FirstObjectSpeed_Y      428 non-null    int64
#  11  SecondObjectSpeed_X     428 non-null    int64
#  12  SecondObjectSpeed_Y     428 non-null    int64
#  13  ThirdObjectSpeed_X      428 non-null    int64
#  14  ThirdObjectSpeed_Y      428 non-null    int64
#  15  FourthObjectSpeed_X     428 non-null    int64
#  16  FourthObjectSpeed_Y     428 non-null    int64
#  17  YawRate                 428 non-null    float64
#  18  Timestamp               428 non-null    float64
# dtypes: float64(2), int64(17)
# memory usage: 66.9 KB
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# 0                     8211                   1444                    5455
# 1                     8208                   1443                    5455
# 2                     8211                   1444                    5453
# 3                     8209                   1445                    5452
# 4                     8209                   1445                    5452
# ..                     ...                    ...                     ...
# 423                    782                   -589                    9912
# 424                    825                   -619                    9911
# 425                    820                   -631                    9906
# 426                    840                   -644                    9902
# 427                    829                   -650                    9897
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# 0                     -1153                   3103                  -1237
# 1                     -1153                   3102                  -1237
# 2                     -1160                   3104                  -1232
# 3                     -1166                   3104                  -1232
# 4                     -1167                   3106                  -1225
# ..                      ...                    ...                    ...
# 423                   -2071                      0                      0
# 424                   -2065                      0                      0
# 425                   -2060                      0                      0
# 426                   -2047                      0                      0
# 427                   -2041                      0                      0
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# 0                     12024                    1715             0
# 1                         0                       0             0
# 2                         0                       0             0
# 3                         0                       0             0
# 4                         0                       0             0
# ..                      ...                     ...           ...
# 423                    1145                    -733             0
# 424                    1144                    -733             0
# 425                    1146                    -730             0
# 426                    1145                    -730             0
# 427                    1142                    -728             0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# 0                    -2                   0                    4
# 1                    -4                   0                   -2
# 2                    -3                   0                   -1
# 3                    -4                   0                    0
# 4                     0                   1                    0
# ..                  ...                 ...                  ...
# 423                 280                -176                   10
# 424                 696                -153                    3
# 425                 674                -153                   10
# 426                 672                -129                   11
# 427                 580                 -78                    5
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# 0                      1                   1                   7
# 1                      3                   0                   6
# 2                     -9                   5                   8
# 3                    -14                   3                  12
# 4                    -11                   8                  16
# ..                   ...                 ...                 ...
# 423                   34                   0                   0
# 424                   38                   0                   0
# 425                   31                   0                   0
# 426                   35                   0                   0
# 427                   35                   0                   0
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp
# 0                      7                    0  0.000000  33.241504
# 1                      0                    0  0.000000  33.335960
# 2                      0                    0  0.000000  33.429725
# 3                      0                    0  0.000000  33.522769
# 4                      0                    0  0.000000  33.618715
# ..                   ...                  ...       ...        ...
# 423                    1                  -10 -0.001343  72.804477
# 424                    7                   -5 -0.001343  72.889443
# 425                   18                   -5 -0.001343  72.972855
# 426                   19                   -3 -0.001343  73.057103
# 427                   32                   -7 -0.001343  73.143584
#
# [428 rows x 19 columns]

# %%
dists = ["FirstObjectDistance_X", "FirstObjectDistance_Y","SecondObjectDistance_X", "SecondObjectDistance_Y","ThirdObjectDistance_X", "ThirdObjectDistance_Y","FourthObjectDistance_X", "FourthObjectDistance_Y"]
for  dist in dists:
    DevelopmentData[dist] /= 128
DevelopmentData
# Out:
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# 0                64.148438              11.281250               42.617188
# 1                64.125000              11.273438               42.617188
# 2                64.148438              11.281250               42.601562
# 3                64.132812              11.289062               42.593750
# 4                64.132812              11.289062               42.593750
# ..                     ...                    ...                     ...
# 423               6.109375              -4.601562               77.437500
# 424               6.445312              -4.835938               77.429688
# 425               6.406250              -4.929688               77.390625
# 426               6.562500              -5.031250               77.359375
# 427               6.476562              -5.078125               77.320312
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# 0                 -9.007812              24.242188              -9.664062
# 1                 -9.007812              24.234375              -9.664062
# 2                 -9.062500              24.250000              -9.625000
# 3                 -9.109375              24.250000              -9.625000
# 4                 -9.117188              24.265625              -9.570312
# ..                      ...                    ...                    ...
# 423              -16.179688               0.000000               0.000000
# 424              -16.132812               0.000000               0.000000
# 425              -16.093750               0.000000               0.000000
# 426              -15.992188               0.000000               0.000000
# 427              -15.945312               0.000000               0.000000
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# 0                 93.937500               13.398438             0
# 1                  0.000000                0.000000             0
# 2                  0.000000                0.000000             0
# 3                  0.000000                0.000000             0
# 4                  0.000000                0.000000             0
# ..                      ...                     ...           ...
# 423                8.945312               -5.726562             0
# 424                8.937500               -5.726562             0
# 425                8.953125               -5.703125             0
# 426                8.945312               -5.703125             0
# 427                8.921875               -5.687500             0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# 0                    -2                   0                    4
# 1                    -4                   0                   -2
# 2                    -3                   0                   -1
# 3                    -4                   0                    0
# 4                     0                   1                    0
# ..                  ...                 ...                  ...
# 423                 280                -176                   10
# 424                 696                -153                    3
# 425                 674                -153                   10
# 426                 672                -129                   11
# 427                 580                 -78                    5
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# 0                      1                   1                   7
# 1                      3                   0                   6
# 2                     -9                   5                   8
# 3                    -14                   3                  12
# 4                    -11                   8                  16
# ..                   ...                 ...                 ...
# 423                   34                   0                   0
# 424                   38                   0                   0
# 425                   31                   0                   0
# 426                   35                   0                   0
# 427                   35                   0                   0
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp
# 0                      7                    0  0.000000  33.241504
# 1                      0                    0  0.000000  33.335960
# 2                      0                    0  0.000000  33.429725
# 3                      0                    0  0.000000  33.522769
# 4                      0                    0  0.000000  33.618715
# ..                   ...                  ...       ...        ...
# 423                    1                  -10 -0.001343  72.804477
# 424                    7                   -5 -0.001343  72.889443
# 425                   18                   -5 -0.001343  72.972855
# 426                   19                   -3 -0.001343  73.057103
# 427                   32                   -7 -0.001343  73.143584
#
# [428 rows x 19 columns]

# %%
DevelopmentData["VehicleSpeed"] /= 256
DevelopmentData
# Out:
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# 0                64.148438              11.281250               42.617188
# 1                64.125000              11.273438               42.617188
# 2                64.148438              11.281250               42.601562
# 3                64.132812              11.289062               42.593750
# 4                64.132812              11.289062               42.593750
# ..                     ...                    ...                     ...
# 423               6.109375              -4.601562               77.437500
# 424               6.445312              -4.835938               77.429688
# 425               6.406250              -4.929688               77.390625
# 426               6.562500              -5.031250               77.359375
# 427               6.476562              -5.078125               77.320312
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# 0                 -9.007812              24.242188              -9.664062
# 1                 -9.007812              24.234375              -9.664062
# 2                 -9.062500              24.250000              -9.625000
# 3                 -9.109375              24.250000              -9.625000
# 4                 -9.117188              24.265625              -9.570312
# ..                      ...                    ...                    ...
# 423              -16.179688               0.000000               0.000000
# 424              -16.132812               0.000000               0.000000
# 425              -16.093750               0.000000               0.000000
# 426              -15.992188               0.000000               0.000000
# 427              -15.945312               0.000000               0.000000
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# 0                 93.937500               13.398438           0.0
# 1                  0.000000                0.000000           0.0
# 2                  0.000000                0.000000           0.0
# 3                  0.000000                0.000000           0.0
# 4                  0.000000                0.000000           0.0
# ..                      ...                     ...           ...
# 423                8.945312               -5.726562           0.0
# 424                8.937500               -5.726562           0.0
# 425                8.953125               -5.703125           0.0
# 426                8.945312               -5.703125           0.0
# 427                8.921875               -5.687500           0.0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# 0                    -2                   0                    4
# 1                    -4                   0                   -2
# 2                    -3                   0                   -1
# 3                    -4                   0                    0
# 4                     0                   1                    0
# ..                  ...                 ...                  ...
# 423                 280                -176                   10
# 424                 696                -153                    3
# 425                 674                -153                   10
# 426                 672                -129                   11
# 427                 580                 -78                    5
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# 0                      1                   1                   7
# 1                      3                   0                   6
# 2                     -9                   5                   8
# 3                    -14                   3                  12
# 4                    -11                   8                  16
# ..                   ...                 ...                 ...
# 423                   34                   0                   0
# 424                   38                   0                   0
# 425                   31                   0                   0
# 426                   35                   0                   0
# 427                   35                   0                   0
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp
# 0                      7                    0  0.000000  33.241504
# 1                      0                    0  0.000000  33.335960
# 2                      0                    0  0.000000  33.429725
# 3                      0                    0  0.000000  33.522769
# 4                      0                    0  0.000000  33.618715
# ..                   ...                  ...       ...        ...
# 423                    1                  -10 -0.001343  72.804477
# 424                    7                   -5 -0.001343  72.889443
# 425                   18                   -5 -0.001343  72.972855
# 426                   19                   -3 -0.001343  73.057103
# 427                   32                   -7 -0.001343  73.143584
#
# [428 rows x 19 columns]

# %%
vels = ["FirstObjectSpeed_X", "FirstObjectSpeed_Y","SecondObjectSpeed_X", "SecondObjectSpeed_Y","ThirdObjectSpeed_X", "ThirdObjectSpeed_Y","FourthObjectSpeed_X", "FourthObjectSpeed_Y"]

for vel in vels:
    DevelopmentData[vel] /= 256

# %%
DevelopmentData["Timestamp"] -= DevelopmentData.Timestamp.min()
DevelopmentData
# Out:
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# 0                64.148438              11.281250               42.617188
# 1                64.125000              11.273438               42.617188
# 2                64.148438              11.281250               42.601562
# 3                64.132812              11.289062               42.593750
# 4                64.132812              11.289062               42.593750
# ..                     ...                    ...                     ...
# 423               6.109375              -4.601562               77.437500
# 424               6.445312              -4.835938               77.429688
# 425               6.406250              -4.929688               77.390625
# 426               6.562500              -5.031250               77.359375
# 427               6.476562              -5.078125               77.320312
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# 0                 -9.007812              24.242188              -9.664062
# 1                 -9.007812              24.234375              -9.664062
# 2                 -9.062500              24.250000              -9.625000
# 3                 -9.109375              24.250000              -9.625000
# 4                 -9.117188              24.265625              -9.570312
# ..                      ...                    ...                    ...
# 423              -16.179688               0.000000               0.000000
# 424              -16.132812               0.000000               0.000000
# 425              -16.093750               0.000000               0.000000
# 426              -15.992188               0.000000               0.000000
# 427              -15.945312               0.000000               0.000000
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# 0                 93.937500               13.398438           0.0
# 1                  0.000000                0.000000           0.0
# 2                  0.000000                0.000000           0.0
# 3                  0.000000                0.000000           0.0
# 4                  0.000000                0.000000           0.0
# ..                      ...                     ...           ...
# 423                8.945312               -5.726562           0.0
# 424                8.937500               -5.726562           0.0
# 425                8.953125               -5.703125           0.0
# 426                8.945312               -5.703125           0.0
# 427                8.921875               -5.687500           0.0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# 0             -0.007812            0.000000             0.015625
# 1             -0.015625            0.000000            -0.007812
# 2             -0.011719            0.000000            -0.003906
# 3             -0.015625            0.000000             0.000000
# 4              0.000000            0.003906             0.000000
# ..                  ...                 ...                  ...
# 423            1.093750           -0.687500             0.039062
# 424            2.718750           -0.597656             0.011719
# 425            2.632812           -0.597656             0.039062
# 426            2.625000           -0.503906             0.042969
# 427            2.265625           -0.304688             0.019531
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# 0               0.003906            0.003906            0.027344
# 1               0.011719            0.000000            0.023438
# 2              -0.035156            0.019531            0.031250
# 3              -0.054688            0.011719            0.046875
# 4              -0.042969            0.031250            0.062500
# ..                   ...                 ...                 ...
# 423             0.132812            0.000000            0.000000
# 424             0.148438            0.000000            0.000000
# 425             0.121094            0.000000            0.000000
# 426             0.136719            0.000000            0.000000
# 427             0.136719            0.000000            0.000000
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp
# 0               0.027344             0.000000  0.000000   0.000000
# 1               0.000000             0.000000  0.000000   0.094456
# 2               0.000000             0.000000  0.000000   0.188222
# 3               0.000000             0.000000  0.000000   0.281266
# 4               0.000000             0.000000  0.000000   0.377212
# ..                   ...                  ...       ...        ...
# 423             0.003906            -0.039062 -0.001343  39.562973
# 424             0.027344            -0.019531 -0.001343  39.647940
# 425             0.070312            -0.019531 -0.001343  39.731351
# 426             0.074219            -0.011719 -0.001343  39.815599
# 427             0.125000            -0.027344 -0.001343  39.902080
#
# [428 rows x 19 columns]

# %%
DevelopmentData["TimestampDiff"] = DevelopmentData.Timestamp.diff()
DevelopmentData
# Out:
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# 0                64.148438              11.281250               42.617188
# 1                64.125000              11.273438               42.617188
# 2                64.148438              11.281250               42.601562
# 3                64.132812              11.289062               42.593750
# 4                64.132812              11.289062               42.593750
# ..                     ...                    ...                     ...
# 423               6.109375              -4.601562               77.437500
# 424               6.445312              -4.835938               77.429688
# 425               6.406250              -4.929688               77.390625
# 426               6.562500              -5.031250               77.359375
# 427               6.476562              -5.078125               77.320312
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# 0                 -9.007812              24.242188              -9.664062
# 1                 -9.007812              24.234375              -9.664062
# 2                 -9.062500              24.250000              -9.625000
# 3                 -9.109375              24.250000              -9.625000
# 4                 -9.117188              24.265625              -9.570312
# ..                      ...                    ...                    ...
# 423              -16.179688               0.000000               0.000000
# 424              -16.132812               0.000000               0.000000
# 425              -16.093750               0.000000               0.000000
# 426              -15.992188               0.000000               0.000000
# 427              -15.945312               0.000000               0.000000
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# 0                 93.937500               13.398438           0.0
# 1                  0.000000                0.000000           0.0
# 2                  0.000000                0.000000           0.0
# 3                  0.000000                0.000000           0.0
# 4                  0.000000                0.000000           0.0
# ..                      ...                     ...           ...
# 423                8.945312               -5.726562           0.0
# 424                8.937500               -5.726562           0.0
# 425                8.953125               -5.703125           0.0
# 426                8.945312               -5.703125           0.0
# 427                8.921875               -5.687500           0.0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# 0             -0.007812            0.000000             0.015625
# 1             -0.015625            0.000000            -0.007812
# 2             -0.011719            0.000000            -0.003906
# 3             -0.015625            0.000000             0.000000
# 4              0.000000            0.003906             0.000000
# ..                  ...                 ...                  ...
# 423            1.093750           -0.687500             0.039062
# 424            2.718750           -0.597656             0.011719
# 425            2.632812           -0.597656             0.039062
# 426            2.625000           -0.503906             0.042969
# 427            2.265625           -0.304688             0.019531
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# 0               0.003906            0.003906            0.027344
# 1               0.011719            0.000000            0.023438
# 2              -0.035156            0.019531            0.031250
# 3              -0.054688            0.011719            0.046875
# 4              -0.042969            0.031250            0.062500
# ..                   ...                 ...                 ...
# 423             0.132812            0.000000            0.000000
# 424             0.148438            0.000000            0.000000
# 425             0.121094            0.000000            0.000000
# 426             0.136719            0.000000            0.000000
# 427             0.136719            0.000000            0.000000
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp  \
# 0               0.027344             0.000000  0.000000   0.000000
# 1               0.000000             0.000000  0.000000   0.094456
# 2               0.000000             0.000000  0.000000   0.188222
# 3               0.000000             0.000000  0.000000   0.281266
# 4               0.000000             0.000000  0.000000   0.377212
# ..                   ...                  ...       ...        ...
# 423             0.003906            -0.039062 -0.001343  39.562973
# 424             0.027344            -0.019531 -0.001343  39.647940
# 425             0.070312            -0.019531 -0.001343  39.731351
# 426             0.074219            -0.011719 -0.001343  39.815599
# 427             0.125000            -0.027344 -0.001343  39.902080
#
#      TimestampDiff
# 0              NaN
# 1         0.094456
# 2         0.093766
# 3         0.093044
# 4         0.095946
# ..             ...
# 423       0.082599
# 424       0.084966
# 425       0.083411
# 426       0.084248
# 427       0.086481
#
# [428 rows x 20 columns]

# %%
plt.plot(DevelopmentData.Timestamp, DevelopmentData.YawRate)

plt.show()

# %%
plt.plot(DevelopmentData.Timestamp, DevelopmentData.VehicleSpeed)

plt.show()

# %%
plt.plot(DevelopmentData.Timestamp,DevelopmentData.Timestamp.diff())
plt.show()

# %%
posx = [0.0]
posy = [0.0]
for i, row in DevelopmentData.iterrows():
    if i!=0:
        posx.append(posx[i-1] + DevelopmentData.iloc[i-1].VehicleSpeed*row.TimestampDiff*np.cos(DevelopmentData.iloc[i-1].YawRate))
        posy.append(posy[i-1] + DevelopmentData.iloc[i-1].VehicleSpeed*row.TimestampDiff*np.sin(DevelopmentData.iloc[i-1].YawRate))
plt.scatter(posx, posy, c=DevelopmentData.Timestamp, cmap="cool")
positions = np.array([posy,posy]).T
plt.colorbar()
plt.show()
positions.shape
# Out:
# (428, 2)

# %%
def rotate_vector(dist):
    result = []
    for i, pos in enumerate(dist):
        RotM = np.array([[np.cos(DevelopmentData.iloc[i].YawRate), np.sin(DevelopmentData.iloc[i].YawRate)],
                [-1.0*np.sin(DevelopmentData.iloc[i].YawRate), np.cos(DevelopmentData.iloc[i].YawRate)]
                ])
        result.append(np.matmul(pos, RotM))
    return np.array(result)

# %%
plt.scatter(posx+DevelopmentData.FirstObjectDistance_X, posy+DevelopmentData.FirstObjectDistance_Y, c=DevelopmentData.Timestamp, cmap="viridis")
plt.colorbar()
plt.show()

# %%
plt.scatter(posx+DevelopmentData.SecondObjectDistance_X, posy+DevelopmentData.SecondObjectDistance_Y, c=DevelopmentData.Timestamp, cmap="viridis")
plt.colorbar()
plt.show()

# %%
plt.scatter(posx + DevelopmentData.ThirdObjectDistance_X, posy + DevelopmentData.ThirdObjectDistance_Y, c=DevelopmentData.Timestamp, cmap="viridis")
plt.colorbar()
plt.show()

# %%
plt.scatter(DevelopmentData.FourthObjectDistance_X, DevelopmentData.FourthObjectDistance_Y, c=DevelopmentData.Timestamp, cmap="viridis", label="Object 4.")
plt.colorbar()
plt.scatter(posx, posy, c=DevelopmentData.Timestamp, cmap="cool", label="Yes")
plt.colorbar()
plt.legend()
plt.show()

# %%
DevelopmentData.to_csv("DevelopmentData_modded.csv", index=False)
DevelopmentData.to_excel("DevelopmentData_final.xlsx", index=False)
